# %% [markdown]
# # **Indian Cars Univariate Analysis**

# %% [markdown]
# Importing All Libraries

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
from matplotlib.pyplot import figure

# %%
df = pd.read_csv("/content/drive/MyDrive/PI-DAintern/Week 6/Indian Cars/cars_ds_final.csv")

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1210.000000          1174.000000  1272.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.660957             0.833763     0.747816
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags  USB_Ports
# count       1270.000000        1141.000000  29.000000
# mean           5.270079           3.787029   1.793103
# std            1.145231           2.522399   0.773642
# min            2.000000           1.000000   1.000000
# 25%            5.000000           2.000000   1.000000
# 50%            5.000000           2.000000   2.000000
# 75%            5.000000           6.000000   2.000000
# max           16.000000          14.000000   3.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 141, dtype: int64

# %%
df.nunique()
# Out:
# Unnamed: 0           1276
# Make                   39
# Model                 263
# Variant              1064
# Ex-Showroom_Price    1179
#                      ...
# USB_Ports               3
# Heads-Up_Display        1
# Welcome_Lights          1
# Battery                 5
# Electric_Range          8
# Length: 141, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 141, dtype: int64

# %%
df[df.duplicated()].count()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df[df.isnull()].count()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df=df.fillna('')
df=df.replace(' ', '')

# %%
df[df.Make =='Tata'].tail()
# Out:
#       Unnamed: 0  Make      Model                Variant Ex-Showroom_Price  \
# 1141        1141  Tata    Harrier  Revotorq Dark Edition     Rs. 17,30,755
# 1187        1187  Tata  Tiago Nrg          1.2L Revotron      Rs. 5,94,993
# 1188        1188  Tata  Tiago Nrg         1.05L Revotorq      Rs. 6,89,993
# 1189        1189  Tata  Tiago Nrg      1.2L Revotron Amt      Rs. 6,39,993
# 1204        1204  Tata     Winger                    15S     Rs. 12,05,000
#
#      Displacement Cylinders Valves_Per_Cylinder               Drivetrain  \
# 1141      1956 cc       3.0                 4.0  FWD (Front Wheel Drive)
# 1187      1199 cc       3.0                 4.0  FWD (Front Wheel Drive)
# 1188      1047 cc       3.0                 4.0  FWD (Front Wheel Drive)
# 1189      1199 cc       3.0                 4.0  FWD (Front Wheel Drive)
# 1204      2200 cc       4.0                      FWD (Front Wheel Drive)
#
#      Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 1141                In-line  ...                                          Yes
# 1187                In-line  ...
# 1188                In-line  ...
# 1189                In-line  ...
# 1204                      V  ...
#
#      Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 1141                                Yes
# 1187
# 1188
# 1189
# 1204
#
#      Heads-Up_Display Welcome_Lights Battery Electric_Range
# 1141
# 1187
# 1188
# 1189
# 1204
#
# [5 rows x 141 columns]

# %%
fig = plt.figure(figsize = (10,20))
ax = fig.subplots()
df.Make.value_counts().plot(ax=ax, kind='pie')
ax.set_ylabel("")
ax.set_title("Top Car Making Companies in India")
plt.show()

# %% [markdown]
# **DATA CLEANING**

# %%
df = pd.read_csv("/content/drive/MyDrive/PI-DAintern/Week 6/Indian Cars/cars_ds_final.csv")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 141, dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-32-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.fillna(df.mode().iloc[0], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Make                 0
# Model                0
# Variant              0
# Ex-Showroom_Price    0
#                     ..
# USB_Ports            0
# Heads-Up_Display     0
# Welcome_Lights       0
# Battery              0
# Electric_Range       0
# Length: 141, dtype: int64

# %%
df.to_csv("/content/drive/MyDrive/PI-DAintern/Week 6/Indian Cars/New Dataset", index = False)

# %%
from sklearn.impute import SimpleImputer

# %%
# Removing rows with missing data
df_cleaned_rows = df.dropna()

# Missing Values (using mean as an example)
df_cleaned = df.select_dtypes(include=np.number)
imputer = SimpleImputer(strategy="mean")
df_imputed = pd.DataFrame(imputer.fit_transform(df_cleaned), columns=df_cleaned.columns)

# Displaying few rows from dataset
print("Cleaned DataFrame (removing rows):")
print(df_cleaned_rows.head())

print("Imputed DataFrame:")
print(df_imputed.head())
# Out:
# Cleaned DataFrame (removing rows):
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      Yes                 Yes
# 1                In-line  ...                      Yes                 Yes
# 2                In-line  ...                      Yes                 Yes
# 3                In-line  ...                      Yes                 Yes
# 4                In-line  ...                      Yes                 Yes
#
#                   Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 0  Revotron 1.2 L, BS6 Engine                    Yes            Yes  1.793103
# 1  Revotron 1.2 L, BS6 Engine                    Yes            Yes  1.793103
# 2  Revotron 1.2 L, BS6 Engine                    Yes            Yes  1.793103
# 3  Revotron 1.2 L, BS6 Engine                    Yes            Yes  1.793103
# 4  Revotron 1.2 L, BS6 Engine                    Yes            Yes  1.793103
#
#   Heads-Up_Display Welcome_Lights          Battery      Electric_Range
# 0              Yes            Yes  200 ampere-hour  110 km/full charge
# 1              Yes            Yes  200 ampere-hour  110 km/full charge
# 2              Yes            Yes  200 ampere-hour  110 km/full charge
# 3              Yes            Yes  200 ampere-hour  110 km/full charge
# 4              Yes            Yes  200 ampere-hour  110 km/full charge
#
# [5 rows x 141 columns]
# Imputed DataFrame:
#    Unnamed: 0  Cylinders  Valves_Per_Cylinder  Doors  Seating_Capacity  \
# 0         0.0        2.0                  2.0    5.0               4.0
# 1         1.0        2.0                  2.0    5.0               4.0
# 2         2.0        2.0                  2.0    4.0               4.0
# 3         3.0        2.0                  2.0    5.0               4.0
# 4         4.0        2.0                  2.0    5.0               4.0
#
#    Number_of_Airbags  USB_Ports
# 0           3.787029   1.793103
# 1           3.787029   1.793103
# 2           3.787029   1.793103
# 3           3.787029   1.793103
# 4           3.787029   1.793103

# %% [markdown]
# DATA TYPES

# %%
data_types = df.dtypes
print(data_types)
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
df.rename(columns={'categorical_column': 'new_column_name'}, inplace=True)

# %%
if 'date_column' in df.columns:
    # Converting the 'date_column' to DateTime format
    df['date_column'] = pd.to_datetime(df['date_column'])

# %%
if 'numeric_column' in df.columns:
    df['numeric_column'] = pd.to_numeric(df['numeric_column'], errors='coerce')

# %%
df['column_with_missing_values'] = np.nan                          # Impute with a specific value
df.dropna(subset=['column_with_missing_values'], inplace=True)

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# Make                           object
# Model                          object
# Variant                        object
# Ex-Showroom_Price              object
#                                ...
# Heads-Up_Display               object
# Welcome_Lights                 object
# Battery                        object
# Electric_Range                 object
# column_with_missing_values    float64
# Length: 142, dtype: object

# %% [markdown]
# **DESCRIPTIVE STATISTICS**

# %%
df = pd.read_csv("/content/drive/MyDrive/PI-DAintern/Week 6/Indian Cars/cars_ds_final.csv")

# %%
df
# Out:
#       Unnamed: 0        Make      Model        Variant Ex-Showroom_Price  \
# 0              0        Tata  Nano Genx             Xt      Rs. 2,92,667
# 1              1        Tata  Nano Genx             Xe      Rs. 2,36,447
# 2              2        Tata  Nano Genx        Emax Xm      Rs. 2,96,661
# 3              3        Tata  Nano Genx            Xta      Rs. 3,34,768
# 4              4        Tata  Nano Genx             Xm      Rs. 2,72,223
# ...          ...         ...        ...            ...               ...
# 1271        1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000
# 1272        1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000
# 1273        1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000
# 1274        1274       Honda       City   V Cvt Petrol     Rs. 12,01,000
# 1275        1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560
#
#      Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0          624 cc        2.0                  2.0   RWD (Rear Wheel Drive)
# 1          624 cc        2.0                  2.0   RWD (Rear Wheel Drive)
# 2          624 cc        2.0                  2.0   RWD (Rear Wheel Drive)
# 3          624 cc        2.0                  2.0   RWD (Rear Wheel Drive)
# 4          624 cc        2.0                  2.0   RWD (Rear Wheel Drive)
# ...           ...        ...                  ...                      ...
# 1271      1498 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1272      1498 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1273      1497 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1274      1497 cc        4.0                  4.0  FWD (Front Wheel Drive)
# 1275      3200 cc        4.0                  4.0    AWD (All Wheel Drive)
#
#      Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                   In-line  ...                      NaN                 NaN
# 1                   In-line  ...                      NaN                 NaN
# 2                   In-line  ...                      NaN                 NaN
# 3                   In-line  ...                      NaN                 NaN
# 4                   In-line  ...                      NaN                 NaN
# ...                     ...  ...                      ...                 ...
# 1271                In-line  ...                      Yes                 NaN
# 1272                In-line  ...                      Yes                 Yes
# 1273                In-line  ...                      Yes                 Yes
# 1274                In-line  ...                      NaN                 NaN
# 1275                In-line  ...                      Yes                 NaN
#
#      Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 0            NaN                    NaN            NaN       NaN
# 1            NaN                    NaN            NaN       NaN
# 2            NaN                    NaN            NaN       NaN
# 3            NaN                    NaN            NaN       NaN
# 4            NaN                    NaN            NaN       NaN
# ...          ...                    ...            ...       ...
# 1271         NaN                    NaN            Yes       NaN
# 1272         NaN                    NaN            Yes       NaN
# 1273         NaN                    NaN            Yes       NaN
# 1274         NaN                    NaN            Yes       NaN
# 1275         NaN                    Yes            Yes       NaN
#
#      Heads-Up_Display Welcome_Lights Battery  Electric_Range
# 0                 NaN            NaN     NaN             NaN
# 1                 NaN            NaN     NaN             NaN
# 2                 NaN            NaN     NaN             NaN
# 3                 NaN            NaN     NaN             NaN
# 4                 NaN            NaN     NaN             NaN
# ...               ...            ...     ...             ...
# 1271              NaN            NaN     NaN             NaN
# 1272              NaN            NaN     NaN             NaN
# 1273              NaN            NaN     NaN             NaN
# 1274              NaN            NaN     NaN             NaN
# 1275              NaN            NaN     NaN             NaN
#
# [1276 rows x 141 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0    Cylinders  Valves_Per_Cylinder        Doors  \
# count  1276.000000  1210.000000          1174.000000  1272.000000
# mean    637.500000     4.380992             3.977853     4.550314
# std     368.493781     1.660957             0.833763     0.747816
# min       0.000000     2.000000             1.000000     2.000000
# 25%     318.750000     4.000000             4.000000     4.000000
# 50%     637.500000     4.000000             4.000000     5.000000
# 75%     956.250000     4.000000             4.000000     5.000000
# max    1275.000000    16.000000            16.000000     5.000000
#
#        Seating_Capacity  Number_of_Airbags  USB_Ports
# count       1270.000000        1141.000000  29.000000
# mean           5.270079           3.787029   1.793103
# std            1.145231           2.522399   0.773642
# min            2.000000           1.000000   1.000000
# 25%            5.000000           2.000000   1.000000
# 50%            5.000000           2.000000   2.000000
# 75%            5.000000           6.000000   2.000000
# max           16.000000          14.000000   3.000000

# %%
mean_values = df.mean()
print("Mean:")
print(mean_values)
# Out:
# Mean:
# Unnamed: 0             637.500000
# Cylinders                4.380992
# Valves_Per_Cylinder      3.977853
# Doors                    4.550314
# Seating_Capacity         5.270079
# Number_of_Airbags        3.787029
# USB_Ports                1.793103
# dtype: float64
# <ipython-input-49-ad5273b01ee3>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = df.mean()

# %%
median_values = df.median()
print("Median:")
print(median_values)
# Out:
# Median:
# Unnamed: 0             637.5
# Cylinders                4.0
# Valves_Per_Cylinder      4.0
# Doors                    5.0
# Seating_Capacity         5.0
# Number_of_Airbags        2.0
# USB_Ports                2.0
# dtype: float64
# <ipython-input-50-46f925545421>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_values = df.median()

# %%
mode_values = df.mode().iloc[0]
print("Mode:")
print(mode_values)
# Out:
# Mode:
# Unnamed: 0                            0
# Make                      Maruti Suzuki
# Model                             Nexon
# Variant                             Lxi
# Ex-Showroom_Price          Rs. 9,99,900
#                             ...
# USB_Ports                           1.0
# Heads-Up_Display                    Yes
# Welcome_Lights                      Yes
# Battery                 200 ampere-hour
# Electric_Range       110 km/full charge
# Name: 0, Length: 141, dtype: object

# %%
min_values = df.min()
print("Minimum:")
print(min_values)

# maximum for all numeric columns
max_values = df.max()
print("Maximum:")
print(max_values)
# Out:
# Minimum:
# Unnamed: 0                           0
# Model                         3-Series
# Variant                          1.0 S
# Ex-Showroom_Price      Rs. 1,01,44,987
# Cylinders                          2.0
# Valves_Per_Cylinder                1.0
# Fuel_Type                          CNG
# Length                         2752 mm
# Doors                              2.0
# Power                    100PS@3600rpm
# Seating_Capacity                   2.0
# Number_of_Airbags                  1.0
# USB_Ports                          1.0
# dtype: object
# Maximum:
# Unnamed: 0                      1275
# Model                          Zs Ev
# Variant                 Zxi Plus Amt
# Ex-Showroom_Price      Rs. 99,00,000
# Cylinders                       16.0
# Valves_Per_Cylinder             16.0
# Fuel_Type                     Petrol
# Length                       6092 mm
# Doors                            5.0
# Power                   99PS@6000rpm
# Seating_Capacity                16.0
# Number_of_Airbags               14.0
# USB_Ports                        3.0
# dtype: object
# <ipython-input-52-497d31364400>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   min_values = df.min()
# <ipython-input-52-497d31364400>:6: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   max_values = df.max()

# %%
std_deviation_values = df.std()
print("Standard Deviation:")
print(std_deviation_values)
# Out:
# Standard Deviation:
# Unnamed: 0             368.493781
# Cylinders                1.660957
# Valves_Per_Cylinder      0.833763
# Doors                    0.747816
# Seating_Capacity         1.145231
# Number_of_Airbags        2.522399
# USB_Ports                0.773642
# dtype: float64
# <ipython-input-53-2ce580b8d61d>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std_deviation_values = df.std()

# %% [markdown]
# **HISTOGRAM**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'column_1': [20,40,60,80,100,120],
    'column_2': [5,50,62,79,95,105],
    'column_3': [38,56,23,45,67,89]
})

# %%
numeric_columns_to_visualize = ['column_1', 'column_2','column_3']

# %%
plt.figure(figsize=(12, 6))
for i, column in enumerate(numeric_columns_to_visualize, 1):
    plt.subplot(1, len(numeric_columns_to_visualize), i)
    plt.hist(df[column], bins=20, edgecolor='green', color='red')
    plt.title(f'Histogram of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **BAR CHARTS**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'column_1': ['Category_A', 'Category_B', 'Category_A', 'Category_A', 'Category_B'],
    'column_2': ['Type_X', 'Type_Y', 'Type_X', 'Type_Y', 'Type_X'],
    'column_3': ['Label_1', 'Label_2', 'Label_1', 'Label_3', 'Label_2'],
})

# %%
columns_to_visualize = ['column_1', 'column_2', 'column_3']

# %%
columns_to_visualize = ['column_1', 'column_2']

# %%
counts = df[columns_to_visualize].apply(pd.value_counts)

# %%
counts.T.plot(kind='bar', stacked=True, figsize=(18, 10), colormap='magma')
plt.title('Categorical Variables', fontsize=30)
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend(title='Categorical Variable', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# **BOX PLOT**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'numeric_column_1': [5, 10, 15, 20, 25, 30, 35, 40, 45],
    'numeric_column_2': [100, 150, 200, 250, 300, 350, 400, 450, 500],
    'numeric_column_3': [10, 20, 30, 40, 50, 60, 70, 80, 90],
})

# %%
numeric_columns_to_visualize = ['numeric_column_1', 'numeric_column_2']

# %%
sns.set_palette("husl")

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[numeric_columns_to_visualize], orient='h', width=0.9)

plt.title('Box Plots of Numeric Variables', fontsize= 20)
plt.xlabel('Values', fontsize=18)
plt.ylabel('Numeric Variables', fontsize=18)

plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **PIE CHART**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'car_model': ['Sedan', 'SUV', 'Hatchback', 'Sedan', 'SUV', 'SUV', 'Hatchback', 'Sedan'],
    'manufacturer': ['Toyota', 'Honda', 'Ford', 'Toyota', 'Honda', 'Ford', 'Nissan', 'Toyota'],
    'color': ['Red', 'Blue', 'Black', 'White', 'Red', 'Blue', 'Black', 'White']
})

# %%
categorical_column_to_visualize = 'car_model'

# %%
categorical_column_to_visualize = 'car_model'

# %%
category_contribution = df[categorical_column_to_visualize].value_counts()

# %%
category_contribution.plot.pie(autopct='%1.1f%%', startangle=90, figsize=(7,7))
plt.title(f'Contribution of {categorical_column_to_visualize}', fontsize=20)
plt.show()

# %% [markdown]
# **COUNT PLOTS**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/PI-DAintern/Week 6/Indian Cars/cars_ds_final.csv")

# %%
(df.columns)
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Variant', 'Ex-Showroom_Price',
#        'Displacement', 'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=141)

# %%
(df.dtypes)
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
df.rename(columns={'category_column': 'new_column_name'}, inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df, y='Body_Type',alpha=.6,color='red')
plt.title('categorical variables',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(' ')
plt.ylabel(' ');

# %% [markdown]
# # **Bivariate Analysis**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/PI-DAintern/Week 6/Indian Cars/cars_ds_final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# 1                In-line  ...                      NaN                 NaN
# 2                In-line  ...                      NaN                 NaN
# 3                In-line  ...                      NaN                 NaN
# 4                In-line  ...                      NaN                 NaN
#
#   Engine_Type ASR_/_Traction_Control Cruise_Control USB_Ports  \
# 0         NaN                    NaN            NaN       NaN
# 1         NaN                    NaN            NaN       NaN
# 2         NaN                    NaN            NaN       NaN
# 3         NaN                    NaN            NaN       NaN
# 4         NaN                    NaN            NaN       NaN
#
#   Heads-Up_Display Welcome_Lights Battery  Electric_Range
# 0              NaN            NaN     NaN             NaN
# 1              NaN            NaN     NaN             NaN
# 2              NaN            NaN     NaN             NaN
# 3              NaN            NaN     NaN             NaN
# 4              NaN            NaN     NaN             NaN
#
# [5 rows x 141 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 141 entries, Unnamed: 0 to Electric_Range
# dtypes: float64(6), int64(1), object(134)
# memory usage: 1.4+ MB

# %%
df.nunique()
# Out:
# Unnamed: 0           1276
# Make                   39
# Model                 263
# Variant              1064
# Ex-Showroom_Price    1179
#                      ...
# USB_Ports               3
# Heads-Up_Display        1
# Welcome_Lights          1
# Battery                 5
# Electric_Range          8
# Length: 141, dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-86-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Unnamed: 0  Cylinders  Valves_Per_Cylinder     Doors  \
# Unnamed: 0             1.000000   0.127391             0.021407 -0.087279
# Cylinders              0.127391   1.000000            -0.000935 -0.507423
# Valves_Per_Cylinder    0.021407  -0.000935             1.000000 -0.029962
# Doors                 -0.087279  -0.507423            -0.029962  1.000000
# Seating_Capacity       0.066246  -0.318495            -0.024687  0.521476
# Number_of_Airbags      0.202458   0.458069             0.068139 -0.220540
# USB_Ports              0.085713  -0.241612                  NaN  0.472499
#
#                      Seating_Capacity  Number_of_Airbags  USB_Ports
# Unnamed: 0                   0.066246           0.202458   0.085713
# Cylinders                   -0.318495           0.458069  -0.241612
# Valves_Per_Cylinder         -0.024687           0.068139        NaN
# Doors                        0.521476          -0.220540   0.472499
# Seating_Capacity             1.000000          -0.011740   0.278574
# Number_of_Airbags           -0.011740           1.000000   0.364222
# USB_Ports                    0.278574           0.364222   1.000000

# %%
correlation_matrix = df.corr()
# Out:
# <ipython-input-87-68bbfff3c4eb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
fig = plt.figure(figsize=(20,18))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', linewidths=.8)
plt.title('Correlation Matrix')

# Show the plot using fig.show() instead of plt.show()
fig.show()

# %% [markdown]
# **Scatter Plots**

# %%
np.random.seed(50)
x = np.random.rand(100)
y = 3 * x + 1 + 0.1 * np.random.randn(100)

# Create scatter plot
plt.scatter(x, y, color='red', marker='h', label='Data Points')

# Add labels and title
plt.title('Scatter Plot: Relationship between X and Y')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plot
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Pair Plots**

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the Iris dataset from Scikit-learn
iris_sklearn = load_iris()

iris = pd.DataFrame(data=iris_sklearn.data, columns=iris_sklearn.feature_names)

iris['target'] = iris_sklearn.target
sns.pairplot(iris, hue='target')  # Use 'target' instead of 'species'
plt.show()

# %% [markdown]
# **Bar Charts with Hue**

# %%
data = {
    'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Value': [20,30,40,50,60,80],
    'Additional_Category': ['X', 'Y', 'X', 'Y', 'X', 'Y']
}

# %%
df = pd.DataFrame(data)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Value', hue='Additional_Category', data=df, palette='Set2')

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Bar Chart with Hue Parameter')

# Show the plot
plt.show()

# %% [markdown]
# **Heatmaps**

# %%
np.random.seed(50)
data = np.random.rand(20,10)

# %%
correlation_matrix = np.corrcoef(data, rowvar=False)

# %%
sns.heatmap(correlation_matrix, annot=True,cmap='viridis', xticklabels=False, yticklabels=False)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# **Joint Plots**

# %%
np.random.seed(50)
x = np.random.rand(300)
y = 5 * x + 2 + 0.1 * np.random.randn(300)  # Linear relationship with some noise
data = np.column_stack((x, y))
sns.jointplot(x=data[:, 0], y=data[:, 1], kind='scatter', marginal_kws=dict(bins=20, fill=False))
plt.show()

# %% [markdown]
# **Box Plots with Hue**

# %%
data = {
    'Day': ['Thur', 'Fri', 'Sat', 'Sun', 'Thur', 'Fri', 'Sat', 'Sun'],
    'Total_Bill': [29.0, 85.5, 50.8, 70.2, 78.7, 15.0, 75.5, 85.0],
    'Sex': ['Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female']
}
df = pd.DataFrame(data)

# %%
sns.boxplot(x='Day', y='Total_Bill', hue='Sex', data=df)
plt.title('Box Plot with Hue')
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.legend(title='Sex', loc='upper right')
plt.show()

# %% [markdown]
# **Categorical Plots**

# %%
#Create categorical plots
np.random.seed(42)
categories = np.random.choice(['A', 'B', 'C'], size=200)
values = np.random.normal(loc=0, scale=1, size=200)

df = pd.DataFrame({'categorical_variable': categories, 'numeric_variable': values})

sns.boxplot(x='categorical_variable', y='numeric_variable', data=df)
plt.show()

sns.violinplot(x='categorical_variable', y='numeric_variable', data=df)
plt.show()

sns.barplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd')
plt.show()

sns.countplot(x='categorical_variable', data=df)
plt.show()

sns.pointplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd')
plt.show()
# Out:
# <ipython-input-102-ed6ebaf34ebd>:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd')
# <ipython-input-102-ed6ebaf34ebd>:20: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.pointplot(x='categorical_variable', y='numeric_variable', data=df, ci='sd')

# %% [markdown]
# **Violin Plots**

# %%
data = pd.DataFrame({
    'Category': ['A']*200 + ['B']*250 + ['C']*300,
    'Numeric_Variable': list(np.random.randn(200)) + list(np.random.randn(250) + 2) + list(np.random.randn(300) - 2)
})

# %%
plt.figure(figsize=(20, 16))
sns.violinplot(x='Category', y='Numeric_Variable', data=data)
plt.title('Distribution of Numeric Variable Across different Categories')
plt.xlabel('Category')
plt.ylabel('Numeric Variable')
plt.show()

# %% [markdown]
# **Stacked Bar Charts**

# %%
data = pd.DataFrame({
    'Category': ['A', 'B', 'C'],
    'Contribution_1': [37, 46, 95],
    'Contribution_2': [26, 55, 80],
    'Contribution_3': [35, 25, 70],
})

# Create a stacked bar chart
plt.figure(figsize=(10, 5))
bottom = [0] * len(data['Category'])

for i, column in enumerate(data.columns[1:]):
    plt.bar(data['Category'], data[column], label=column, bottom=bottom)
    bottom = [sum(x) for x in zip(bottom, data[column])]

plt.title('Combined Contribution of Different Categories')
plt.xlabel('DifferentCategory')
plt.ylabel('Contribution')
plt.legend(title='Contributions', loc='upper right')
plt.show()

# %% [markdown]
# **Insights and Documentation**

# %%
desc_stats = iris.describe()
print(desc_stats)
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
print(df.columns)
# Out:
# Index(['categorical_variable', 'numeric_variable'], dtype='object')

# %%
correlation_matrix = iris.corr()

# Plot heatmap
plt.figure(figsize=(10, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='plasma', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
plt.scatter(x, y, alpha=0.5)
plt.title('Scatter Plot of Two Numeric Variables')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.grid(True)
plt.show()

# %% [markdown]
# **Box Plot**

# %%
np.random.seed(100)
your_data = np.random.normal(0, 1, 100)  # Replace this with your actual dataset

# Create a box plot
plt.figure(figsize=(10, 5))
sns.boxplot(x=your_data)
plt.title('Box Plot of Numerical Variable')
plt.xlabel('Numerical Variable')
plt.show()
